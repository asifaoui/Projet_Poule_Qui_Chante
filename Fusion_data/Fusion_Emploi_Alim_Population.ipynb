# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#import du fichier CSV Fusion_Donnee_Alimentaire_Population.csv

data_C = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Fusion_Donnee_Alimentaire_Population.csv',decimal=".", index_col=0)
data_C.head()
# Out:
#                         Zone  Disponibilité alimentaire (Kcal/personne/jour)  \
# Code zone
# 1                    Arménie                                            54.0
# 2                Afghanistan                                             5.0
# 3                    Albanie                                            85.0
# 4                    Algérie                                            22.0
# 5          Samoa américaines                                             NaN
#
#            Quantité Aliments_disponible Poules(Milliers tonnes)  \
# Code zone
# 1                                                      235.0
# 2                                                      254.0
# 3                                                      438.0
# 4                                                     4858.0
# 5                                                        NaN
#
#            Export_Utile(Milliers tonnes)  Taux de croissance_population [%]
# Code zone
# ...

# %%
data_C.shape
# Out:
# (238, 5)

# %%
#import du fichier CSV Emlpoi_prod_animale

prod_animale = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Emlpoi_prod_animale.csv',decimal=".", index_col=0)
prod_animale.head()
# Out:
#                   Zone  Emploi dans la production_vegetale_animale (1000No)
# Code zone
# 1              Arménie                                             339.74
# 2          Afghanistan                                            1185.84
# 3              Albanie                                             421.64
# 7               Angola                                            5998.46
# 9            Argentine                                              68.22

# %%
prod_animale.shape
# Out:
# (142, 2)

# %%
# jointure des dataframes data_dispo_calorie + df_alimentation_animeaux + data_export_import + poplation_taux_croissance
# + Emploi dans la production_vegetale_animale

data_D = data_C.merge(prod_animale, on=["Code zone","Zone"], how='outer')
display(data_D)
# Out:
#                                           Zone  \
# Code zone
# 1                                      Arménie
# 2                                  Afghanistan
# 3                                      Albanie
# 4                                      Algérie
# 5                            Samoa américaines
# ...                                        ...
# 279                                    Curaçao
# 280        Sint Maarten  (partie néerlandaise)
# 281            Saint-Martin (partie française)
# 282                           Saint-Barthélemy
# 299                                  Palestine
#
#            Disponibilité alimentaire (Kcal/personne/jour)  \
# Code zone
# 1                                                    54.0
# 2                                                     5.0
# 3                                                    85.0
# 4                                                    22.0
# 5                                                     NaN
# ...

# %%
#préparation de l'export du dataframe en fichier CSV

data_D.to_csv('/content/drive/MyDrive/Colab Notebooks/Fusion_Emploi_Alim_Population.csv', index=True)
