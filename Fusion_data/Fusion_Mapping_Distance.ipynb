# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#import du fichier CSV Fusion_FR_Mapping.csv

data_join_FR = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Fusion_FR_Mapping.csv',decimal=".")

data_join_FR.head()
# Out:
#    Unnamed: 0         Zone Country Code  Numeric  Code zone  \
# 0           0       Kosovo          XKX    983.0         -1
# 1           1      Armenia          ARM     51.0          1
# 2           2  Afghanistan          AFG      4.0          2
# 3           3      Albania          ALB      8.0          3
# 4           4      Algeria          DZA     12.0          4
#
#    Disponibilité alimentaire (Kcal/personne/jour)  \
# 0                                             NaN
# 1                                            54.0
# 2                                             5.0
# 3                                            85.0
# 4                                            22.0
#
#    Quantité Aliments_disponible Poules(Milliers tonnes)  \
# 0                                                NaN
# 1                                              235.0
# 2                                              254.0
# 3                                              438.0
# ...

# %%
#import du fichier CSV france_dist_eco.csv

france_dist_eco = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/france_dist_eco.csv',decimal=".")

france_dist_eco.head()
# Out:
#   Country Code  Distance_Economique Pays_France(Km)
# 0          ABW                             7711.830
# 1          AFG                             5489.888
# 2          AGO                             6363.600
# 3          AIA                             6737.844
# 4          ALB                             1461.321

# %%
# jointure des 2 dataframes sur 1 colonnes Country Code

Mapping_Distance = data_join_FR.merge(france_dist_eco, on=["Country Code"], how='outer')
display(Mapping_Distance)
# Out:
#      Unnamed: 0          Zone Country Code  Numeric  Code zone  \
# 0          21.0         Aruba          ABW    533.0       22.0
# 1           2.0   Afghanistan          AFG      4.0        2.0
# 2           7.0        Angola          AGO     24.0        7.0
# 3         227.0      Anguilla          AIA    660.0      258.0
# 4           3.0       Albania          ALB      8.0        3.0
# ..          ...           ...          ...      ...        ...
# 245         NaN           NaN          YUG      NaN        NaN
# 246       183.0  South Africa          ZAF    710.0      202.0
# 247         NaN           NaN          ZAR      NaN        NaN
# 248       224.0        Zambia          ZMB    894.0      251.0
# 249       162.0      Zimbabwe          ZWE    716.0      181.0
#
#      Disponibilité alimentaire (Kcal/personne/jour)  \
# 0                                               NaN
# 1                                               5.0
# ...

# %%
#Suppression de la colonne Unnamed: 0
Mapping_Distance = Mapping_Distance.drop('Unnamed: 0', axis=1)
Mapping_Distance.head()
# Out:
#           Zone Country Code  Numeric  Code zone  \
# 0        Aruba          ABW    533.0       22.0
# 1  Afghanistan          AFG      4.0        2.0
# 2       Angola          AGO     24.0        7.0
# 3     Anguilla          AIA    660.0      258.0
# 4      Albania          ALB      8.0        3.0
#
#    Disponibilité alimentaire (Kcal/personne/jour)  \
# 0                                             NaN
# 1                                             5.0
# 2                                            35.0
# 3                                             NaN
# 4                                            85.0
#
#    Quantité Aliments_disponible Poules(Milliers tonnes)  \
# 0                                                NaN
# 1                                              254.0
# 2                                             5873.0
# 3                                                NaN
# 4                                              438.0
#
# ...

# %%
#vérification des valeurs manquantes
print(Mapping_Distance.isnull().sum())
# Out:
# Zone                                                      9
# Country Code                                              0
# Numeric                                                   9
# Code zone                                                 9
# Disponibilité alimentaire (Kcal/personne/jour)           78
# Quantité Aliments_disponible Poules(Milliers tonnes)     76
# Export_Utile(Milliers tonnes)                            78
# Taux de croissance_population [%]                        14
# Emploi dans la production_vegetale_animale (1000No)     108
# Distance_Economique Pays_France(Km)                      24
# dtype: int64

# %%
#Détail des valeurs manquantes pour la variable Zone
Mapping_Distance.loc[Mapping_Distance['Zone'].isnull(),:]
# Out:
#     Zone Country Code  Numeric  Code zone  \
# 37   NaN          CCK      NaN        NaN
# 54   NaN          CXR      NaN        NaN
# 158  NaN          NFK      NaN        NaN
# 170  NaN          PAL      NaN        NaN
# 172  NaN          PCN      NaN        NaN
# 186  NaN          ROM      NaN        NaN
# 220  NaN          TMP      NaN        NaN
# 245  NaN          YUG      NaN        NaN
# 247  NaN          ZAR      NaN        NaN
#
#      Disponibilité alimentaire (Kcal/personne/jour)  \
# 37                                              NaN
# 54                                              NaN
# 158                                             NaN
# 170                                             NaN
# 172                                             NaN
# 186                                             NaN
# 220                                             NaN
# 245                                             NaN
# 247                                             NaN
#
# ...

# %%
Mapping_Distance.loc[37,'Zone']= 'Cocos Islands'
Mapping_Distance.loc[37,'Numeric']= 166
Mapping_Distance.loc[54,'Zone']= 'Christmas Island'
Mapping_Distance.loc[54,'Numeric']= 162
Mapping_Distance.loc[158,'Zone']= 'Norfolk Island'
Mapping_Distance.loc[158,'Numeric']= 574
Mapping_Distance.loc[172,'Zone']= 'Pitcairn'
Mapping_Distance.loc[172,'Numeric']= 612

# %%
Mapping_Distance.loc[182,'Distance_Economique Pays_France(Km)']= 3168.216

# %%
print(Mapping_Distance.loc[Mapping_Distance['Country Code']== 'PSE'])
# Out:
#           Zone Country Code  Numeric  Code zone  \
# 182  Palestine          PSE    275.0      299.0
#
#      Disponibilité alimentaire (Kcal/personne/jour)  \
# 182                                             NaN
#
#      Quantité Aliments_disponible Poules(Milliers tonnes)  \
# 182                                                NaN
#
#      Export_Utile(Milliers tonnes)  Taux de croissance_population [%]  \
# 182                            NaN                              50.84
#
#      Emploi dans la production_vegetale_animale (1000No)  \
# 182                                              46.46
#
#      Distance_Economique Pays_France(Km)
# 182                             3168.216

# %%
print(Mapping_Distance.loc[Mapping_Distance['Country Code']== 'ZAF'])
#Country code ZAR : pas trouvé
# Out:
#              Zone Country Code  Numeric  Code zone  \
# 246  South Africa          ZAF    710.0      202.0
#
#      Disponibilité alimentaire (Kcal/personne/jour)  \
# 246                                           143.0
#
#      Quantité Aliments_disponible Poules(Milliers tonnes)  \
# 246                                             5357.0
#
#      Export_Utile(Milliers tonnes)  Taux de croissance_population [%]  \
# 246                          451.0                              28.52
#
#      Emploi dans la production_vegetale_animale (1000No)  \
# 246                                             931.43
#
#      Distance_Economique Pays_France(Km)
# 246                             8750.608

# %%
print(Mapping_Distance.loc[Mapping_Distance['Country Code']== 'ROU'])
# Out:
#         Zone Country Code  Numeric  Code zone  \
# 187  Romania          ROU    642.0      183.0
#
#      Disponibilité alimentaire (Kcal/personne/jour)  \
# 187                                            66.0
#
#      Quantité Aliments_disponible Poules(Milliers tonnes)  \
# 187                                             7718.0
#
#      Export_Utile(Milliers tonnes)  Taux de croissance_population [%]  \
# 187                           77.0                             -11.89
#
#      Emploi dans la production_vegetale_animale (1000No)  \
# 187                                             867.68
#
#      Distance_Economique Pays_France(Km)
# 187                                  NaN

# %%
Mapping_Distance.loc[187,'Distance_Economique Pays_France(Km)']= 1723.568

# %%
print(Mapping_Distance.loc[Mapping_Distance['Country Code']== 'TLS'])
# Out:
#             Zone Country Code  Numeric  Code zone  \
# 219  Timor-Leste          TLS    626.0      176.0
#
#      Disponibilité alimentaire (Kcal/personne/jour)  \
# 219                                            14.0
#
#      Quantité Aliments_disponible Poules(Milliers tonnes)  \
# 219                                                6.0
#
#      Export_Utile(Milliers tonnes)  Taux de croissance_population [%]  \
# 219                    -121.185185                              43.38
#
#      Emploi dans la production_vegetale_animale (1000No)  \
# 219                                             168.23
#
#      Distance_Economique Pays_France(Km)
# 219                                  NaN

# %%
Mapping_Distance.loc[219,'Distance_Economique Pays_France(Km)']= 13172.920

# %%
print(Mapping_Distance.loc[Mapping_Distance['Country Code']== 'SRB'])
# Out:
#        Zone Country Code  Numeric  Code zone  \
# 201  Serbia          SRB    688.0      272.0
#
#      Disponibilité alimentaire (Kcal/personne/jour)  \
# 201                                            35.0
#
#      Quantité Aliments_disponible Poules(Milliers tonnes)  \
# 201                                             2833.0
#
#      Export_Utile(Milliers tonnes)  Taux de croissance_population [%]  \
# 201                            5.0                              -3.75
#
#      Emploi dans la production_vegetale_animale (1000No)  \
# 201                                             433.37
#
#      Distance_Economique Pays_France(Km)
# 201                                  NaN

# %%
print(Mapping_Distance.loc[Mapping_Distance['Country Code']== 'XKX'])
# Out:
#        Zone Country Code  Numeric  Code zone  \
# 243  Kosovo          XKX    983.0       -1.0
#
#      Disponibilité alimentaire (Kcal/personne/jour)  \
# 243                                             NaN
#
#      Quantité Aliments_disponible Poules(Milliers tonnes)  \
# 243                                                NaN
#
#      Export_Utile(Milliers tonnes)  Taux de croissance_population [%]  \
# 243                            NaN                                NaN
#
#      Emploi dans la production_vegetale_animale (1000No)  \
# 243                                                NaN
#
#      Distance_Economique Pays_France(Km)
# 243                                  NaN

# %%
print(Mapping_Distance.loc[Mapping_Distance['Country Code']== 'MNE'])
# Out:
#            Zone Country Code  Numeric  Code zone  \
# 144  Montenegro          MNE    499.0      273.0
#
#      Disponibilité alimentaire (Kcal/personne/jour)  \
# 144                                            55.0
#
#      Quantité Aliments_disponible Poules(Milliers tonnes)  \
# 144                                               41.0
#
#      Export_Utile(Milliers tonnes)  Taux de croissance_population [%]  \
# 144                            8.0                               1.61
#
#      Emploi dans la production_vegetale_animale (1000No)  \
# 144                                                NaN
#
#      Distance_Economique Pays_France(Km)
# 144                                  NaN

# %%
#La yogosslavie n'existe plus aujourd'hui: parmis les pays qui la composaient et qui n'ont pas de Distance_Economique Pays_France(Km)
# et qui ont assez de données qu'on peut explorer on trouve la Serbie et Montenegro : Nous mettrons à jour la valeur de Distance_Economique Pays_France(Km)
Mapping_Distance.loc[201,'Distance_Economique Pays_France(Km)']= 1397.047
Mapping_Distance.loc[144,'Distance_Economique Pays_France(Km)']= 1397.047

# %%
#Détail des valeurs manquantes pour la variable Zone
Mapping_Distance.loc[Mapping_Distance['Zone'].isnull(),:]
# Out:
#     Zone Country Code  Numeric  Code zone  \
# 170  NaN          PAL      NaN        NaN
# 186  NaN          ROM      NaN        NaN
# 220  NaN          TMP      NaN        NaN
# 245  NaN          YUG      NaN        NaN
# 247  NaN          ZAR      NaN        NaN
#
#      Disponibilité alimentaire (Kcal/personne/jour)  \
# 170                                             NaN
# 186                                             NaN
# 220                                             NaN
# 245                                             NaN
# 247                                             NaN
#
#      Quantité Aliments_disponible Poules(Milliers tonnes)  \
# 170                                                NaN
# 186                                                NaN
# 220                                                NaN
# 245                                                NaN
# 247                                                NaN
#
# ...

# %%
# Mise à jour effectué au niveau des Zone --> Suppression des lignes
Mapping_Distance = Mapping_Distance[Mapping_Distance['Zone'].notna()]

# %%
#vérification des valeurs manquantes
print(Mapping_Distance.isnull().sum())
# Out:
# Zone                                                      0
# Country Code                                              0
# Numeric                                                   0
# Code zone                                                 4
# Disponibilité alimentaire (Kcal/personne/jour)           73
# Quantité Aliments_disponible Poules(Milliers tonnes)     71
# Export_Utile(Milliers tonnes)                            73
# Taux de croissance_population [%]                         9
# Emploi dans la production_vegetale_animale (1000No)     103
# Distance_Economique Pays_France(Km)                      19
# dtype: int64

# %%
#Détail des valeurs manquantes pour la variable Code Zone
Mapping_Distance.loc[Mapping_Distance['Code zone'].isnull(),:]
# Out:
#                  Zone Country Code  Numeric  Code zone  \
# 37      Cocos Islands          CCK    166.0        NaN
# 54   Christmas Island          CXR    162.0        NaN
# 158    Norfolk Island          NFK    574.0        NaN
# 172          Pitcairn          PCN    612.0        NaN
#
#      Disponibilité alimentaire (Kcal/personne/jour)  \
# 37                                              NaN
# 54                                              NaN
# 158                                             NaN
# 172                                             NaN
#
#      Quantité Aliments_disponible Poules(Milliers tonnes)  \
# 37                                                 NaN
# 54                                                 NaN
# 158                                                NaN
# 172                                                NaN
#
#      Export_Utile(Milliers tonnes)  Taux de croissance_population [%]  \
# ...

# %%
Mapping_Distance.head()
# Out:
#           Zone Country Code  Numeric  Code zone  \
# 0        Aruba          ABW    533.0       22.0
# 1  Afghanistan          AFG      4.0        2.0
# 2       Angola          AGO     24.0        7.0
# 3     Anguilla          AIA    660.0      258.0
# 4      Albania          ALB      8.0        3.0
#
#    Disponibilité alimentaire (Kcal/personne/jour)  \
# 0                                             NaN
# 1                                             5.0
# 2                                            35.0
# 3                                             NaN
# 4                                            85.0
#
#    Quantité Aliments_disponible Poules(Milliers tonnes)  \
# 0                                                NaN
# 1                                              254.0
# 2                                             5873.0
# 3                                                NaN
# 4                                              438.0
#
# ...

# %%
#préparation de l'export du dataframe en fichier CSV

Mapping_Distance.to_csv('/content/drive/MyDrive/Colab Notebooks/Mapping_Distance.csv', index=True)
