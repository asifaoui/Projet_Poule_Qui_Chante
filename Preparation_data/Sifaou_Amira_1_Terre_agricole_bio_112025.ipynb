# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#lecture du fichier terre agricole bio téléchargé du site Fibl : Ils publient chaque année
#des statistiques sur la surface agricole gérée en bio dans chaque pays — c’est-à-dire le nombre d’hectares certifiés bio.

df_terre_agricole = pd.read_csv('/content/drive/MyDrive/Colab_Projet_Poule/Terre_agricole_bio.csv')
df_terre_agricole.shape
# Out:
# (159, 2)

# %%
df_terre_agricole.head()
# Out:
#      Country  Organic area share of total farmland [%]
# 0    Albania                                      0.06
# 1    Algeria                                      0.01
# 2    Andorra                                      0.01
# 3  Argentina                                      3.43
# 4    Armenia                                      0.03

# %%
#Verification de type des variables
df_terre_agricole.dtypes
# Out:
# Country                                      object
# Organic area share of total farmland [%]    float64
# dtype: object

# %%
#vérification des valeurs manquantes
print(df_terre_agricole.isnull().sum())
# Out:
# Country                                     0
# Organic area share of total farmland [%]    0
# dtype: int64

# %%
# Renommage de la colonne country en Zone
df_terre_agricole = df_terre_agricole.rename(columns={'Country': 'Zone'})
df_terre_agricole
# Out:
#                                    Zone  \
# 0                               Albania
# 1                               Algeria
# 2                               Andorra
# 3                             Argentina
# 4                               Armenia
# ..                                  ...
# 154                             Vanuatu
# 155  Venezuela (Bolivarian Republic of)
# 156                            Viet Nam
# 157                              Zambia
# 158                            Zimbabwe
#
#      Organic area share of total farmland [%]
# 0                                        0.06
# 1                                        0.01
# 2                                        0.01
# 3                                        3.43
# 4                                        0.03
# ..                                        ...
# 154                                      3.44
# 155                                      0.01
# 156                                      1.41
# ...

# %%
df_terre_agricole = df_terre_agricole.rename(columns={'Organic area share of total farmland [%]': '[%]surfaces agricoles biologiques/total des terres agricoles'})

# %%
#Verification s'il y a des outliers
df_terre_agricole.describe()
# Out:
#        [%]surfaces agricoles biologiques/total des terres agricoles
# count                                         159.000000
# mean                                            3.822956
# std                                             6.644402
# min                                             0.000000
# 25%                                             0.130000
# 50%                                             0.790000
# 75%                                             3.735000
# max                                            44.580000

# %%
#Vérification des Doublons
df_terre_agricole.loc[df_terre_agricole[['Zone', '[%]surfaces agricoles biologiques/total des terres agricoles']].duplicated(keep=False),:]
# Out:
# Empty DataFrame
# Columns: [Zone, [%]surfaces agricoles biologiques/total des terres agricoles]
# Index: []

# %%
#préparation de l'export du dataframe en fichier CSV

df_terre_agricole.to_csv('/content/drive/MyDrive/Colab Notebooks/Terre_agricole_bio.csv', index=False)
